# %%
import pandas as pd
import numpy as np

# %%
np.random.randint(1,7)
# Out:
# 3

# %%
dice = pd.Series([1,2,3,4,5,6])

# %%
dice.mean()
# Out:
# 3.5

# %%
np.random.randint(1,7,size=10)
# Out:
# array([3, 1, 3, 4, 3, 5, 3, 3, 1, 4])

# %%
dice.sample(100,replace=True).mean()
# Out:
# 3.48

# %%
При увеличении кол-ва экспериментов в сэмпле - средняя будет ближе к истинной средней
(закон больших чисел)

# %%
result = []
for n in range(1,1000):
    result.append(dice.sample(n,replace=True).mean())

# %%
result[:10]
# Out:
# [6.0,
#  5.0,
#  1.6666666666666667,
#  2.75,
#  3.0,
#  3.5,
#  3.142857142857143,
#  3.375,
#  3.6666666666666665,
#  3.6]

# %%
pd.Series(result).plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
result = [dice.sample(n,replace=True).mean() for n in range(1,1000)]

# %%
pd.Series([dice.sample(n,replace=True).mean() for n in range(1,1000)]).plot()
# Out:
# <AxesSubplot:>
